# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Bringing-Old-Photos-Back-to-Life
# Out:
# /content/drive/MyDrive/Bringing-Old-Photos-Back-to-Life

# %%
# !python Global/train_domain_A.py \
--use_v2_degradation \
--training_dataset domain_A \
--name domainA_SR_old_photos \
--label_nc 0 \
--loadSize 256 \
--fineSize 256 \
--no_instance \
--resize_or_crop crop_only \
--batchSize 32 --no_html \
--gpu_ids 0 \
--self_gen \
--nThreads 4 \
--n_downsample_global 3 \
--use_vae_which_epoch latest \
--which_epoch latest \
--k_size 4 --use_v2 --mc 64 --start_r 1 --kl 1 --no_cgan \
--dataroot "/content/drive/MyDrive/Bringing-Old-Photos-Back-to-Life/old2life" \
--outputs_dir "/content/drive/MyDrive/Bringing-Old-Photos-Back-to-Life/output/" \
--checkpoints_dir "/content/drive/MyDrive/Bringing-Old-Photos-Back-to-Life/checkpoints" \
--niter 10 \
--niter_decay 10
# Out:
# CustomDatasetDataLoader
# dataset [UnPairOldPhotos_SR] was created
# start load bigfile (0.00 GB) into memory
# find total 81 images
# load 0 images done
# load all 81 images done
# start load bigfile (0.01 GB) into memory
# find total 8 images
# load 0 images done
# load all 8 images done
# start load bigfile (0.08 GB) into memory
# find total 1000 images
# load 0 images done
# load all 1000 images done
# -------------Filter the imgs whose size <256 in VOC-------------
# --------Origin image num is [1000], filtered result is [977]--------
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
# ...

# %%
# !python Global/train_domain_B.py \
--use_v2_degradation \
--training_dataset domain_B \
--name domainB_old_photos \
--label_nc 0 \
--loadSize 256 \
--fineSize 256 \
--no_instance \
--resize_or_crop crop_only \
--batchSize 32 --no_html \
--gpu_ids 0 \
--self_gen \
--nThreads 4 \
--n_downsample_global 3 \
--use_vae_which_epoch latest \
--which_epoch latest \
--k_size 4 --use_v2 --mc 64 --start_r 1 --kl 1 --no_cgan \
--dataroot "/content/drive/MyDrive/Bringing-Old-Photos-Back-to-Life/old2life" \
--outputs_dir "/content/drive/MyDrive/Bringing-Old-Photos-Back-to-Life/output/" \
--checkpoints_dir "/content/drive/MyDrive/Bringing-Old-Photos-Back-to-Life/checkpoints" \
--niter 10 \
--niter_decay 10
# Out:
# CustomDatasetDataLoader
# dataset [UnPairOldPhotos_SR] was created
# start load bigfile (0.08 GB) into memory
# find total 1000 images
# load 0 images done
# load all 1000 images done
# -------------Filter the imgs whose size <256 in VOC-------------
# --------Origin image num is [1000], filtered result is [977]--------
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# #training images = 992
# GlobalGenerator_DCDCv2(
#   (encoder): Sequential(
#     (0): ReflectionPad2d((3, 3, 3, 3))
#     (1): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1))
# ...

# %%
# !python Global/train_mapping.py \
--use_v2_degradation \
--training_dataset mapping \
--name mapping_quality \
--label_nc 0 \
--loadSize 256 \
--fineSize 256 \
--no_instance \
--resize_or_crop crop_only \
--batchSize 15 --no_html \
--gpu_ids 0 \
--nThreads 4 \
--l2_feat 60 \
--n_downsample_global 3 \
--mc 64 --k_size 4 \
--start_r 1 --mapping_n_block 6 \
--map_mc 512 --use_l1_feat \
--use_vae_which_epoch latest \
--which_epoch latest \
--load_pretrainA "/content/drive/MyDrive/Bringing-Old-Photos-Back-to-Life/checkpoints/domainA_SR_old_photos" \
--load_pretrainB "/content/drive/MyDrive/Bringing-Old-Photos-Back-to-Life/checkpoints/domainB_old_photos" \
--dataroot "/content/drive/MyDrive/Bringing-Old-Photos-Back-to-Life/old2life" \
--outputs_dir "/content/drive/MyDrive/Bringing-Old-Photos-Back-to-Life/output/" \
--checkpoints_dir "/content/drive/MyDrive/Bringing-Old-Photos-Back-to-Life/checkpoints" \
--niter 10 \
--niter_decay 10
# Out:
# CustomDatasetDataLoader
# dataset [PairOldPhotos] was created
# start load bigfile (0.08 GB) into memory
# find total 1000 images
# load 0 images done
# load all 1000 images done
# -------------Filter the imgs whose size <256 in VOC-------------
# --------Origin image num is [1000], filtered result is [977]--------
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# #training images = 975
# Mapping: You are using the mapping model without global restoration.
# MultiscaleDiscriminator(
#   (scale0_layer0): Sequential(
# ...
